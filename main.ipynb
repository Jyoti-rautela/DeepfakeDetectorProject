# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2 as cv
import torch

print("All libraries working successfully!")
# Out:
# All libraries working successfully!

# %%
df = pd.read_csv("data/train.csv")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Unnamed: 0     100000 non-null  int64
#  1   original_path  100000 non-null  str
#  2   id             100000 non-null  str
#  3   label          100000 non-null  int64
#  4   label_str      100000 non-null  str
#  5   path           100000 non-null  str
# dtypes: int64(2), str(4)
# memory usage: 4.6 MB
