# %% [markdown]
# Download one time and comment again after you will get data folder with all real fake image data sets

# %%
# import kaggle

# # Authenticate (requires kaggle.json in C:\Users\<YourUsername>\.kaggle\)
# kaggle.api.authenticate()

# # Download dataset and unzip into a folder called "data"
# kaggle.api.dataset_download_files(
#     "xhlulu/140k-real-and-fake-faces",
#     path="./data",
#     unzip=True
# )

# print("Dataset downloaded to ./data")
# Out:
# Dataset URL: https://www.kaggle.com/datasets/xhlulu/140k-real-and-fake-faces
# Dataset downloaded to ./data
