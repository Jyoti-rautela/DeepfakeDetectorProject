# %%
pip install torch torchvision
# Out:
# Requirement already satisfied: torch in d:\ZOE\Gen AI\Python\venv\Lib\site-packages (2.11.0)
# Collecting torchvision
#   Downloading torchvision-0.26.0-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Requirement already satisfied: filelock in d:\ZOE\Gen AI\Python\venv\Lib\site-packages (from torch) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in d:\ZOE\Gen AI\Python\venv\Lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools<82 in d:\ZOE\Gen AI\Python\venv\Lib\site-packages (from torch) (80.10.2)
# Requirement already satisfied: sympy>=1.13.3 in d:\ZOE\Gen AI\Python\venv\Lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in d:\ZOE\Gen AI\Python\venv\Lib\site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in d:\ZOE\Gen AI\Python\venv\Lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in d:\ZOE\Gen AI\Python\venv\Lib\site-packages (from torch) (2026.3.0)
# Requirement already satisfied: numpy in d:\ZOE\Gen AI\Python\venv\Lib\site-packages (from torchvision) (2.4.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in d:\ZOE\Gen AI\Python\venv\Lib\site-packages (from torchvision) (12.1.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\ZOE\Gen AI\Python\venv\Lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\ZOE\Gen AI\Python\venv\Lib\site-packages (from jinja2->torch) (3.0.3)
# Downloading torchvision-0.26.0-cp312-cp312-win_amd64.whl (4.3 MB)
#    ---------------------------------------- 0.0/4.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.3 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.3 MB ? eta -:--:--
#    ------------ --------------------------- 1.3/4.3 MB 6.1 MB/s eta 0:00:01
#    ------------------- -------------------- 2.1/4.3 MB 4.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 3.1/4.3 MB 4.5 MB/s eta 0:00:01
#    ------------------------------------ --- 3.9/4.3 MB 4.3 MB/s eta 0:00:01
#    ---------------------------------------- 4.3/4.3 MB 4.2 MB/s  0:00:01
# Installing collected packages: torchvision
# Successfully installed torchvision-0.26.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader

# %%
# These exact values are required for ALL pre-trained models
MEAN = [0.485, 0.456, 0.406]
STD = [0.229, 0.224, 0.225]
train_transforms = transforms.Compose([
transforms.Resize((224, 224)), # resize to 224x224
transforms.RandomHorizontalFlip(),# flip randomly (augmentation)
transforms.ToTensor(), # convert to tensor
transforms.Normalize(MEAN, STD) # normalize
])
val_transforms = transforms.Compose([
transforms.Resize((224, 224)),
transforms.ToTensor(),
transforms.Normalize(MEAN, STD)
])

# %%
# Auto-loads images from folder — 0=fake, 1=real
train_data = ImageFolder('data/real_vs_fake/real-vs-fake/train', transform=train_transforms)
valid_data = ImageFolder('data/real_vs_fake/real-vs-fake/valid', transform=val_transforms)

# %%
# Load in batches of 32
train_loader = DataLoader(train_data, batch_size=32, shuffle=True)
valid_loader = DataLoader(valid_data, batch_size=32, shuffle=False)
print(f'Train: {len(train_data)} images')
print(f'Val: {len(valid_data)} images')
# Out:
# Train: 100000 images
# Val: 20000 images
