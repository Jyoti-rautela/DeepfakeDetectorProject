# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2 as cv
import torch
print(torch.cuda.is_available())       # must print True
print(torch.cuda.get_device_name(0))   # must print NVIDIA GeForce GTX 1650

print("All libraries working successfully!")
# Out:
# True
# NVIDIA GeForce GTX 1650
# All libraries working successfully!
